# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 1000)
x.shape
# Out:
# (1000,)

# %%
xx, yy = np.meshgrid(x, x)
xx.shape, yy.shape
# Out:
# ((1000, 1000), (1000, 1000))

# %%
sns.heatmap(xx)
# Out:
# <Axes: >

# %%
X = xx.reshape(xx.shape[0]*xx.shape[1], 1)
X.shape
# Out:
# (1000000, 1)

# %%
X = np.hstack((X, yy.reshape(yy.shape[0]*yy.shape[1], 1)))
X.shape
# Out:
# (1000000, 2)

# %%
w = np.array([5, 3])
w_0 = -10

y_hat = X @ w + w_0
y_hat.shape
# Out:
# (1000000,)

# %%
y_hat_reshape = y_hat.reshape(xx.shape)
y_hat_reshape
# Out:
# array([[-10.        ,  -9.94994995,  -9.8998999 , ...,  39.8998999 ,
#          39.94994995,  40.        ],
#        [ -9.96996997,  -9.91991992,  -9.86986987, ...,  39.92992993,
#          39.97997998,  40.03003003],
#        [ -9.93993994,  -9.88988989,  -9.83983984, ...,  39.95995996,
#          40.01001001,  40.06006006],
#        ...,
#        [ 19.93993994,  19.98998999,  20.04004004, ...,  69.83983984,
#          69.88988989,  69.93993994],
#        [ 19.96996997,  20.02002002,  20.07007007, ...,  69.86986987,
#          69.91991992,  69.96996997],
#        [ 20.        ,  20.05005005,  20.1001001 , ...,  69.8998999 ,
#          69.94994995,  70.        ]], shape=(1000, 1000))

# %%
plt.contourf(xx, yy, y_hat_reshape)

# %%
plt.contourf(xx, yy, y_hat_reshape>0)
